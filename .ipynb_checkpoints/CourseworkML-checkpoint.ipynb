# %%
import os
import pandas as pd

root_dir = './' # this is to be defined by you 
local_path = 'Data-for-students-regression/' # store the related data files in this folder

data_dir = root_dir + local_path
print(data_dir)
## Define paths to the training data and targets files
training_data_path = data_dir + 'Training_data.csv'
training_targets_path = data_dir + 'Training_data_targets.csv'
# Out:
# ./Data-for-students-regression/

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define root directory and local path for data
root_dir = './'
local_path = 'Data-for-students-regression/'

# Define directory for data files
data_dir = root_dir + local_path

# Define paths to the training data and targets files
training_data_path = data_dir + 'Training_data.csv'
training_targets_path = data_dir + 'Training_data_targets.csv'

# Read in the data and targets
data = pd.read_csv(training_data_path)
targets = pd.read_csv(training_targets_path)

# Plot histograms of all features
data.hist(figsize=(20, 20))
plt.show()

# %%
# Compute correlations of all features with target variable
correlations = data.corrwith(targets['TARGET_deathRate'])

# Sort correlations by strength
correlations = correlations.sort_values(ascending=False)

# Print top five features with strongest correlations
print("Top five features with strongest correlations to target:")
print(correlations[:5])
# Out:
# Top five features with strongest correlations to target:
# incidenceRate             0.443983
# PctPublicCoverageAlone    0.439734
# povertyPercent            0.413260
# PctHS25_Over              0.409915
# PctPublicCoverage         0.391899
# dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes=['incidenceRate', 'PctPublicCoverageAlone', 'povertyPercent', 'PctHS25_Over', 'PctPublicCoverage']

scatter_matrix(data[attributes],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='incidenceRate', ylabel='incidenceRate'>,
#         <Axes: xlabel='PctPublicCoverageAlone', ylabel='incidenceRate'>,
#         <Axes: xlabel='povertyPercent', ylabel='incidenceRate'>,
#         <Axes: xlabel='PctHS25_Over', ylabel='incidenceRate'>,
#         <Axes: xlabel='PctPublicCoverage', ylabel='incidenceRate'>],
#        [<Axes: xlabel='incidenceRate', ylabel='PctPublicCoverageAlone'>,
#         <Axes: xlabel='PctPublicCoverageAlone', ylabel='PctPublicCoverageAlone'>,
#         <Axes: xlabel='povertyPercent', ylabel='PctPublicCoverageAlone'>,
#         <Axes: xlabel='PctHS25_Over', ylabel='PctPublicCoverageAlone'>,
#         <Axes: xlabel='PctPublicCoverage', ylabel='PctPublicCoverageAlone'>],
#        [<Axes: xlabel='incidenceRate', ylabel='povertyPercent'>,
#         <Axes: xlabel='PctPublicCoverageAlone', ylabel='povertyPercent'>,
#         <Axes: xlabel='povertyPercent', ylabel='povertyPercent'>,
#         <Axes: xlabel='PctHS25_Over', ylabel='povertyPercent'>,
#         <Axes: xlabel='PctPublicCoverage', ylabel='povertyPercent'>],
#        [<Axes: xlabel='incidenceRate', ylabel='PctHS25_Over'>,
#         <Axes: xlabel='PctPublicCoverageAlone', ylabel='PctHS25_Over'>,
#         <Axes: xlabel='povertyPercent', ylabel='PctHS25_Over'>,
#         <Axes: xlabel='PctHS25_Over', ylabel='PctHS25_Over'>,
#         <Axes: xlabel='PctPublicCoverage', ylabel='PctHS25_Over'>],
#        [<Axes: xlabel='incidenceRate', ylabel='PctPublicCoverage'>,
#         <Axes: xlabel='PctPublicCoverageAlone', ylabel='PctPublicCoverage'>,
#         <Axes: xlabel='povertyPercent', ylabel='PctPublicCoverage'>,
#         <Axes: xlabel='PctHS25_Over', ylabel='PctPublicCoverage'>,
#         <Axes: xlabel='PctPublicCoverage', ylabel='PctPublicCoverage'>]],
#       dtype=object)

# %%
data.describe()
targets.describe()
# Out:
#        TARGET_deathRate
# count       2438.000000
# mean         178.617104
# std           27.530973
# min           59.700000
# 25%          161.700000
# 50%          178.600000
# 75%          195.175000
# max          362.800000

# %%
from sklearn.model_selection import train_test_split

# assuming X is your data and y is your target variable
X_train, X_test, y_train, y_test = train_test_split(data, targets, test_size=0.2, random_state=42)

# %%
y_train
# Out:
#       TARGET_deathRate
# 2032             164.0
# 2255             182.2
# 651              165.4
# 406              202.2
# 177              206.6
# ...                ...
# 1638             135.0
# 1095             156.8
# 1130             200.2
# 1294             146.8
# 860              115.0
#
# [1950 rows x 1 columns]

# %%
X_test
# Out:
#       avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# 443    162.000000                70     456.800000      36285       25756
# 2075    78.000000                33     425.100000      30668       12574
# 1366  1962.667684               108     453.549422      60322       47710
# 259     18.000000                 7     339.400000      44794        2985
# 2164   249.000000               125     315.200000      75920       87513
# ...           ...               ...            ...        ...         ...
# 307   1962.667684                 6     453.549422      45341        2591
# 2432   232.000000                97     502.700000      39247       37421
# 2078    13.000000                 5     382.000000      35875        2110
# 383    799.000000               319     381.000000      38974      214295
# 1192    11.000000                 4     502.100000      46051        1381
#
#       povertyPercent  studyPerCap  MedianAge  MedianAgeMale  MedianAgeFemale  \
# 443             21.7     0.000000       44.8           43.7             45.9
# 2075            23.2     0.000000       45.3           42.6             47.9
# 1366            10.3     0.000000       49.4           48.7             50.0
# 259             13.6     0.000000       49.9           49.0             50.8
# 2164             4.9   399.940580       37.6           37.2             37.9
# ...              ...          ...        ...            ...              ...
# 307             12.0     0.000000       49.8           49.0             51.9
# 2432            17.7     0.000000       40.3           39.2             41.0
# 2078            19.5     0.000000       46.5           48.4             43.9
# 383             27.9   111.995147       32.4           31.1             34.0
# 1192            15.0     0.000000       52.0           49.8             53.4
#
#       ...  PctPrivateCoverageAlone  PctEmpPrivCoverage  PctPublicCoverage  \
# 443   ...                     38.6                30.1               45.0
# 2075  ...                     33.7                29.0               49.3
# 1366  ...                     48.9                39.6               35.8
# 259   ...                     47.6                30.9               39.5
# 2164  ...                      NaN                62.7               23.0
# ...   ...                      ...                 ...                ...
# 307   ...                     46.7                37.2               38.8
# 2432  ...                      NaN                42.0               39.5
# 2078  ...                     47.4                29.2               34.1
# 383   ...                     37.3                32.0               43.5
# 1192  ...                     50.7                25.6               31.4
#
#       PctPublicCoverageAlone   PctWhite   PctBlack  PctAsian  PctOtherRace  \
# 443                     25.8  94.119691   3.150579  0.324324      0.077220
# 2075                    30.3  57.593458  42.180685  0.093458      0.000000
# 1366                    12.9  89.151273   0.554392  1.305571      3.499862
# 259                     17.7  98.132045   0.128824  0.193237      0.000000
# 2164                    10.6  96.147147   0.735038  1.028821      0.137021
# ...                      ...        ...        ...       ...           ...
# 307                     12.8  91.901273   3.085229  1.195526      0.000000
# 2432                    24.1  91.947096   5.018399  0.338649      0.634633
# 2078                    16.7  96.028369   0.000000  0.000000      0.236407
# 383                     29.9  89.057921   1.730206  1.088506      4.908793
# 1192                    11.4  95.645967   0.713776  0.214133      0.713776
#
#       PctMarriedHouseholds  BirthRate
# 443              52.912572   4.906586
# 2075             44.774323   3.098592
# 1366             56.135295   5.193754
# 259              58.339248   8.058608
# 2164             60.155889   6.401614
# ...                    ...        ...
# 307              53.288926  10.810811
# 2432             53.745657   4.754260
# 2078             53.898305   5.066667
# 383              48.156818   5.880466
# 1192             52.608696   3.361345
#
# [488 rows x 31 columns]

# %%
cancer_df=X_train

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1950 entries, 2032 to 860
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              1950 non-null   float64
#  1   avgDeathsPerYear         1950 non-null   int64
#  2   incidenceRate            1950 non-null   float64
#  3   medIncome                1950 non-null   int64
#  4   popEst2015               1950 non-null   int64
#  5   povertyPercent           1950 non-null   float64
#  6   studyPerCap              1950 non-null   float64
#  7   MedianAge                1950 non-null   float64
#  8   MedianAgeMale            1950 non-null   float64
#  9   MedianAgeFemale          1950 non-null   float64
#  10  AvgHouseholdSize         1950 non-null   float64
#  11  PercentMarried           1950 non-null   float64
#  12  PctNoHS18_24             1950 non-null   float64
#  13  PctHS18_24               1950 non-null   float64
#  14  PctSomeCol18_24          486 non-null    float64
#  15  PctBachDeg18_24          1950 non-null   float64
#  16  PctHS25_Over             1950 non-null   float64
#  17  PctBachDeg25_Over        1950 non-null   float64
#  18  PctEmployed16_Over       1857 non-null   float64
#  19  PctUnemployed16_Over     1950 non-null   float64
#  20  PctPrivateCoverage       1950 non-null   float64
#  21  PctPrivateCoverageAlone  1555 non-null   float64
#  22  PctEmpPrivCoverage       1950 non-null   float64
#  23  PctPublicCoverage        1950 non-null   float64
#  24  PctPublicCoverageAlone   1950 non-null   float64
#  25  PctWhite                 1950 non-null   float64
#  26  PctBlack                 1950 non-null   float64
#  27  PctAsian                 1950 non-null   float64
#  28  PctOtherRace             1950 non-null   float64
#  29  PctMarriedHouseholds     1950 non-null   float64
#  30  BirthRate                1950 non-null   float64
# dtypes: float64(28), int64(3)
# memory usage: 487.5 KB

# %%
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(strategy="median")

# %%
imputer.fit(cancer_df)
# Out:
# SimpleImputer(strategy='median')

# %%
print(imputer.statistics_)
# Out:
# [1.67000000e+02 6.00000000e+01 4.53549422e+02 4.52855000e+04
#  2.56555000e+04 1.58500000e+01 0.00000000e+00 4.10000000e+01
#  3.96000000e+01 4.24000000e+01 2.49000000e+00 5.25000000e+01
#  1.73000000e+01 3.47000000e+01 4.00500000e+01 5.40000000e+00
#  3.53000000e+01 1.24000000e+01 5.45000000e+01 7.50000000e+00
#  6.52000000e+01 4.86000000e+01 4.11000000e+01 3.64000000e+01
#  1.88000000e+01 9.01169556e+01 2.23113090e+00 5.47588875e-01
#  8.37668018e-01 5.15859800e+01 5.37096309e+00]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

preprocessing_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler())
])

cancer_num_tr = preprocessing_pipeline.fit_transform(cancer_df)

# %%
cancer_num_tr.shape
# Out:
# (1950, 31)

# %% [markdown]
# ### Not a part of coursework but just trying

# %%
from sklearn.linear_model import LinearRegression

lin_reg=LinearRegression()
lin_reg.fit(cancer_num_tr, y_train)
# Out:
# LinearRegression()

# %%
some_data=X_train.iloc[:5]
some_labels=y_train.iloc[:5]
some_data_prepared=preprocessing_pipeline.transform(some_data)
print("Predictions:", lin_reg.predict(some_data_prepared))
print("Labels:", some_labels)
# Out:
# Predictions: [[167.79464588]
#  [193.85580033]
#  [178.47664713]
#  [158.86565492]
#  [190.57094626]]
# Labels:       TARGET_deathRate
# 2032             164.0
# 2255             182.2
# 651              165.4
# 406              202.2
# 177              206.6

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# Fit OLS model
ols = LinearRegression()
ols.fit(cancer_num_tr, y_train)

# Fit Lasso model
alpha_lasso = 0.01 # chosen by cross-validation
lasso = Lasso(alpha=alpha_lasso)
lasso.fit(cancer_num_tr, y_train)

# Fit Ridge model
alpha_ridge =10 # chosen by cross-validation
ridge = Ridge(alpha=alpha_ridge)
ridge.fit(cancer_num_tr, y_train)
# Out:
# Ridge(alpha=10)

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Lasso and Ridge models
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Perform grid search for Lasso model
lasso_cv = GridSearchCV(Lasso(), param_grid, cv=5)
lasso_cv.fit(cancer_num_tr, y_train)

# Perform grid search for Ridge model
ridge_cv = GridSearchCV(Ridge(), param_grid, cv=5)
ridge_cv.fit(cancer_num_tr, y_train)

# Choose best alpha value for Lasso and Ridge models
alpha_lasso = lasso_cv.best_params_['alpha']
alpha_ridge = ridge_cv.best_params_['alpha']

alpha_ridge
# Out:
# 10

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
cancer_predictions = ols.predict(cancer_num_tr)
lin_mse=mean_squared_error(y_train, cancer_predictions)
lin_rmse=np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 19.005585945267338

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
cancer_predictions = lasso.predict(cancer_num_tr)
lin_mse=mean_squared_error(y_train, cancer_predictions)
lin_rmse=np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 19.00651945077674

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
cancer_predictions = ridge.predict(cancer_num_tr)
lin_mse=mean_squared_error(y_train, cancer_predictions)
lin_rmse=np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 19.010478951188606

# %%
from sklearn.model_selection import cross_val_score

scores =cross_val_score(ols, cancer_num_tr,y_train,scoring="neg_mean_squared_error",cv=10)

ols_rmse_scores = np.sqrt(-scores)

def display_scores(scores):
    print('Scores:',scores)
    print('Mean:',scores.mean())
    print('Standard deviation:',scores.std())
    
display_scores(ols_rmse_scores)
# Out:
# Scores: [19.77888993 20.14008856 20.06556413 17.52179242 18.07464459 21.55937154
#  19.20969626 18.53812901 21.07255757 19.8438294 ]
# Mean: 19.580456341946793
# Standard deviation: 1.2053715583637818

# %%
scores =cross_val_score(lasso, cancer_num_tr,y_train,scoring="neg_mean_squared_error",cv=10)

lasso_rmse_scores = np.sqrt(-scores)
display_scores(lasso_rmse_scores)
# Out:
# Scores: [19.7468795  20.08607605 20.08002605 17.50519517 18.08079358 21.53787436
#  19.18357191 18.5346965  21.10019348 19.82579141]
# Mean: 19.568109800290763
# Standard deviation: 1.2057983763783393

# %%
scores =cross_val_score(ridge, cancer_num_tr,y_train,scoring="neg_mean_squared_error",cv=10)

ridge_rmse_scores = np.sqrt(-scores)
display_scores(ridge_rmse_scores)
# Out:
# Scores: [19.69751008 20.01138772 20.14777279 17.48825624 18.0722163  21.47942324
#  19.1804912  18.55107546 21.13643883 19.77922732]
# Mean: 19.554379919549568
# Standard deviation: 1.2021981804831656

# %% [markdown]
# ## actual exercise 3

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Lasso and Ridge models
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Perform grid search for Lasso model
lasso_cv = GridSearchCV(Lasso(), param_grid, cv=10)
lasso_cv.fit(cancer_num_tr, y_train)

# Perform grid search for Ridge model
ridge_cv = GridSearchCV(Ridge(), param_grid, cv=10)
ridge_cv.fit(cancer_num_tr, y_train)

# Choose best alpha value for Lasso and Ridge models
alpha_lasso = lasso_cv.best_params_['alpha']
alpha_ridge = ridge_cv.best_params_['alpha']
alpha_ridge
# Out:
# 10

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# Fit OLS model
ols = LinearRegression()
ols.fit(cancer_num_tr, y_train)

# Fit Lasso model
#alpha_lasso = 0.01 # chosen by cross-validation
lasso = Lasso(alpha=alpha_lasso)
lasso.fit(cancer_num_tr, y_train)

# Fit Ridge model
#alpha_ridge = 0.1 # chosen by cross-validation
ridge = Ridge(alpha=alpha_ridge)
ridge.fit(cancer_num_tr, y_train)
# Out:
# Ridge(alpha=10)

# %%
from sklearn.metrics import mean_squared_error

X_test_prep = preprocessing_pipeline.fit_transform(X_test)
# Evaluate OLS model
ols_pred = ols.predict(X_test_prep)
ols_mse = np.sqrt(mean_squared_error(y_test, ols_pred))

# Evaluate Lasso model
lasso_pred = lasso.predict(X_test_prep)
lasso_mse = np.sqrt(mean_squared_error(y_test, lasso_pred))

# Evaluate Ridge model
ridge_pred = ridge.predict(X_test_prep)
ridge_mse = np.sqrt(mean_squared_error(y_test, ridge_pred))

print(f"RMSE of OLS model: {ols_mse:.3f}")
print(f"RMSE of Lasso model: {lasso_mse:.3f}")
print(f"RMSE of Ridge model: {ridge_mse:.3f}")
# Out:
# RMSE of OLS model: 18.977
# RMSE of Lasso model: 19.030
# RMSE of Ridge model: 18.978

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

# Fit the OLS model to the training data
ols_model =LinearRegression()

# Evaluate OLS model
ols_model.fit(cancer_num_tr, y_train)
ols_predictions = ols_model.predict(X_test_prep)
ols_rmse = np.sqrt(mean_squared_error(y_test, ols_predictions))
print(f"OLS RMSE: {ols_rmse:.3f}")
# Out:
# OLS RMSE: 18.977

# %%
y_train
# Out:
#       TARGET_deathRate
# 2032             164.0
# 2255             182.2
# 651              165.4
# 406              202.2
# 177              206.6
# ...                ...
# 1638             135.0
# 1095             156.8
# 1130             200.2
# 1294             146.8
# 860              115.0
#
# [1950 rows x 1 columns]

# %%
import pandas as pd

# Convert y_train to a Pandas DataFrame
y_train_df = pd.DataFrame(y_train, columns=['TARGET_deathRate'])

# Use the column name to access the index
coef = pd.Series(lasso.coef_, index=y_train_df.columns)

# Rest of the code
important_features = coef.abs().sort_values(ascending=False).head(5)
print(important_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 7
#       4 y_train_df = pd.DataFrame(y_train, columns=['TARGET_deathRate'])
#       6 # Use the column name to access the index
# ----> 7 coef = pd.Series(lasso.coef_, index=y_train_df.columns)
#       9 # Rest of the code
#      10 important_features = coef.abs().sort_values(ascending=False).head(5)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:461, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     459     index = default_index(len(data))
#     460 elif is_list_like(data):
# --> 461     com.require_length_match(data, index)
#     463 # create/copy the manager
#     464 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (31) does not match length of index (1)

# %% [markdown]
# ## Exercise 4

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=alpha_lasso)
lasso.fit(cancer_num_tr, y_train)

coef = pd.Series(lasso.coef_, index=X_train.columns)
important_features = coef.abs().sort_values(ascending=False).head(5)
print(important_features)
# Out:
# incidenceRate           10.092283
# PctBachDeg25_Over        7.222027
# PctPrivateCoverage       6.080492
# PctMarriedHouseholds     5.302948
# PercentMarried           4.469378
# dtype: float64

# %% [markdown]
# ## Exercise 5

# %%
from sklearn.ensemble import RandomForestRegressor

# Create an instance of the RandomForestRegressor class
rf = RandomForestRegressor(random_state=42)

# Fit the model to the training data
rf.fit(cancer_num_tr, y_train)

# Make predictions on the test data
y_pred_rf = rf.predict(X_test_prep)

# Calculate the mean squared error (MSE) of the Random Forest model
rf_mse = mean_squared_error(y_test, y_pred_rf)
rf_rmse = np.sqrt(rf_mse)
print("MSE of Random Forest model:", rf_mse)
print("RMSE of Random Forest model:", rf_rmse)
# Out:
# C:\Users\shrus\AppData\Local\Temp\ipykernel_33056\3487487874.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(cancer_num_tr, y_train)
# MSE of Random Forest model: 414.36174777868854
# RMSE of Random Forest model: 20.35587747503626

# %%
from sklearn.ensemble import RandomForestRegressor

# create a RandomForestRegressor object with 100 estimators
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)

# fit the model to the training data
rf_reg.fit(cancer_num_tr, y_train)

# get the feature importances and sort them in descending order
importances = rf_reg.feature_importances_
indices = np.argsort(importances)[::-1]

# print the top 5 important features
print("Top 5 important features:")
for i in range(5):
    print(f"{i+1}. {X_train.columns[indices[i]]}: {importances[indices[i]]}")
# Out:
# C:\Users\shrus\AppData\Local\Temp\ipykernel_33056\3714572989.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(cancer_num_tr, y_train)
# Top 5 important features:
# 1. PctBachDeg25_Over: 0.21218649760885752
# 2. incidenceRate: 0.19735270419397052
# 3. medIncome: 0.04741156089321718
# 4. PctHS25_Over: 0.043922175954302506
# 5. avgDeathsPerYear: 0.037840824411933385

# %%
## Read in the provided example test data
test_data_path = data_dir + 'Test_data_example.csv'
test_targets_path = data_dir + 'Test_data_example_targets.csv'

data_prepared=preprocessing_pipeline.transform(data)
lin_reg.fit(data_prepared,targets)

test_data = pd.read_csv(test_data_path)
test_targets = pd.read_csv(test_targets_path)
## Retrain your chosen regression model here 
# For example: lin_reg = LinearRegression()
# lin_reg.fit(X_train,y_train) where X_train and y_train is provided training data
# Next write the lines of code required to predict on unseen test data and evaluate your predictions

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

test_data_path = data_dir + 'Test_data_example.csv'
test_targets_path = data_dir + 'Test_data_example_targets.csv'

test_data = pd.read_csv(test_data_path)
test_targets = pd.read_csv(test_targets_path)
test_data_prepared=preprocessing_pipeline.transform(test_data)
data_prepared=preprocessing_pipeline.transform(data)
# Fit the OLS model to the training data
ols_model =LinearRegression()

# Evaluate OLS model
ols_model.fit(data_prepared, targets)
ols_predictions = ols_model.predict(test_data_prepared)
ols_rmse = np.sqrt(mean_squared_error(test_targets, ols_predictions))
print(f"OLS RMSE: {ols_rmse:.3f}")
# Out:
# OLS RMSE: 23.574

# %% [markdown]
# ## Exercise 7

# %%
root_dir = './' # this is to be defined by you 
local_path = 'Data-for-students-classification/' # store the related data files in this folder
data_dir = root_dir + local_path

data_features_path = data_dir + 'Heart-attack-data-predictors.csv'
data_targets_path = data_dir + 'Heart-attack-data-targets.csv'

# %%
data_features_path
# Out:
# './Data-for-students-classification/Heart-attack-data-predictors.csv'

# %%
# Read in the data
heart_data = pd.read_csv(data_features_path)
heart_target=pd.read_csv(data_targets_path)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

heart_data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'AgeAtHeartAttack'}>,
#         <Axes: title={'center': 'PericardialEffusion'}>],
#        [<Axes: title={'center': 'FractionalShortening'}>,
#         <Axes: title={'center': 'epss'}>],
#        [<Axes: title={'center': 'lvdd'}>,
#         <Axes: title={'center': 'WallMotionIndex'}>]], dtype=object)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AgeAtHeartAttack      126 non-null    float64
#  1   PericardialEffusion   131 non-null    int64
#  2   FractionalShortening  124 non-null    float64
#  3   epss                  117 non-null    float64
#  4   lvdd                  121 non-null    float64
#  5   WallMotionIndex       130 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 6.3 KB

# %%
from sklearn.model_selection import train_test_split

# assuming X is your data and y is your target variable
X_train, X_test, y_train, y_test = train_test_split(heart_data, heart_target, test_size=0.2, random_state=42)

# %%
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(strategy="median")
imputer.fit(X_train)
imputer.statistics_
# Out:
# array([62.   ,  0.   ,  0.22 , 10.3  ,  4.665,  1.25 ])

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

preprocessing_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler())
])

X_train_prepared = preprocessing_pipeline.fit_transform(X_train)

# %%
X_train_prepared
# Out:
# array([[-3.78476144e-02, -4.42043322e-01, -1.86817343e-01,
#         -9.65749642e-01,  5.60931778e-01, -8.45788748e-01],
#        [-5.53573895e-01, -4.42043322e-01, -1.74333507e+00,
#          1.26992969e+00,  1.91972030e+00, -1.67558945e-01],
#        [ 9.93604946e-01, -4.42043322e-01,  3.62541856e-01,
#         -4.17116676e-01, -1.87025205e-01, -8.45788748e-01],
#        [ 1.25146809e+00, -4.42043322e-01,  1.00346092e+00,
#         -8.28591400e-01, -9.34982189e-01, -8.45788748e-01],
#        [ 2.02505751e+00, -4.42043322e-01, -6.44616675e-01,
#          7.48728376e-01, -5.98401546e-01, -1.89437326e-01],
#        [-8.11437035e-01, -4.42043322e-01,  1.79422123e-01,
#          3.78401124e-01,  6.35727476e-01, -1.44102796e-02],
#        [ 9.10839556e-02, -4.42043322e-01, -2.78377209e-01,
#         -8.42307224e-01, -1.58321157e+00, -6.05126560e-01],
#        [ 2.20015526e-01, -4.42043322e-01,  1.27814052e+00,
#         -4.44548324e-01,  1.28395686e+00, -8.45788748e-01],
#        [-8.11437035e-01, -4.42043322e-01,  6.37221455e-01,
#         -3.62253379e-01,  2.48959400e-02, -8.45788748e-01],
#        [ 4.77878666e-01, -4.42043322e-01, -5.98836742e-01,
#         -1.01652721e-01,  5.11067979e-01, -8.45788748e-01],
#        [-1.06930017e+00,  2.26222171e+00,  2.70981989e-01,
#          2.99901770e-03, -5.73469647e-01, -8.45788748e-01],
#        [ 9.10839556e-02, -4.42043322e-01, -1.86817343e-01,
#         -6.77717335e-01, -2.11957105e-01, -8.45788748e-01],
#        [ 1.25146809e+00, -4.42043322e-01,  8.78622564e-02,
#          9.48950395e-02,  1.63300345e+00,  2.48130289e-01],
#        [ 4.77878666e-01,  2.26222171e+00,  2.01061945e+00,
#         -4.17116676e-01, -9.84845988e-01,  1.38738386e-01],
#        [-1.71395803e+00, -4.42043322e-01, -7.36176541e-01,
#         -8.79368964e-02, -3.59594704e-05,  2.43596836e+00],
#        [ 9.93604946e-01, -4.42043322e-01, -4.61496942e-01,
#         -1.65154085e+00, -1.24695457e-01, -8.45788748e-01],
#        [-3.78476144e-02, -4.42043322e-01,  7.28781321e-01,
#         -7.05148983e-01, -1.53334778e+00,  2.70008670e-01],
#        [-1.32716331e+00, -4.42043322e-01, -4.61496942e-01,
#         -2.38810962e-01, -7.48316578e-02, -8.45788748e-01],
#        [-1.19823174e+00, -4.42043322e-01,  1.91905958e+00,
#         -3.75969203e-01,  4.98278394e-02, -8.45788748e-01],
#        [-1.06930017e+00, -4.42043322e-01,  5.45661589e-01,
#         -8.97170521e-01, -3.36616602e-01,  9.70116854e-01],
#        [ 9.10839556e-02, -4.42043322e-01, -6.44616675e-01,
#         -7.46296455e-01, -7.23061043e-01, -2.55072468e-01],
#        [-1.19823174e+00, -4.42043322e-01, -3.11655699e-02,
#          8.03591673e-01, -2.61820904e-01, -4.51977895e-01],
#        [ 8.64673376e-01,  2.26222171e+00, -5.53056809e-01,
#          9.81897387e-01,  6.23261527e-01, -8.45788748e-01],
#        [ 1.89612594e+00, -4.42043322e-01, -1.56021534e+00,
#         -2.79958434e-01, -3.86480401e-01, -5.81670411e-02],
#        [-2.95710755e-01, -4.42043322e-01, -3.69937076e-01,
#         -1.65154085e+00, -3.36616602e-01, -2.53494700e-02],
#        [-1.66779184e-01, -4.42043322e-01, -6.44616675e-01,
#         -1.65154085e+00, -2.99218753e-01,  4.90370246e-02],
#        [ 7.35741806e-01, -4.42043322e-01, -6.44616675e-01,
#         -5.64195151e-03,  7.97784823e-01,  5.21610049e-01],
#        [ 1.25146809e+00, -4.42043322e-01, -9.19296274e-01,
#         -2.38810962e-01,  2.53055183e+00,  7.46810112e-03],
#        [-4.24642325e-01, -4.42043322e-01, -9.19296274e-01,
#         -2.52526786e-01, -5.48537747e-01,  6.20062762e-01],
#        [-8.11437035e-01, -4.42043322e-01, -1.68839915e+00,
#         -6.91433159e-01, -7.85390792e-01, -3.42585991e-01],
#        [-1.66779184e-01, -4.42043322e-01, -9.19296274e-01,
#          1.50309870e+00,  1.30888876e+00,  2.06403589e+00],
#        [-2.22968431e+00, -4.42043322e-01,  4.72413695e-01,
#          6.11570135e-01,  7.60386974e-01, -7.14518464e-01],
#        [-1.66779184e-01, -4.42043322e-01,  3.44229882e-01,
#         -3.30735998e-02,  1.49555437e-01, -8.45788748e-01]])

# %%
from sklearn.linear_model import LogisticRegression

# Train logistic regression model without regularisation
logistic_regression = LogisticRegression(max_iter=1000)
logistic_regression.fit(X_train_prepared, np.ravel(y_train))

# Train logistic regression model with L1 regularisation
l1_logistic_regression = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
l1_logistic_regression.fit(X_train_prepared,np.ravel(y_train))

# Train logistic regression model with L2 regularisation
l2_logistic_regression = LogisticRegression(penalty='l2', max_iter=1000)
l2_logistic_regression.fit(X_train_prepared,np.ravel(y_train))
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Define logistic regression models with L1 and L2 regularization
# logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear')
# logreg_l2 = LogisticRegression(penalty='l2')

# Perform cross-validation
cv_scores_l1 = cross_validate(l1_logistic_regression, X_train_prepared, np.ravel(y_train), cv=5,
                              scoring=['accuracy', 'precision', 'recall', 'f1'])
cv_scores_l2 = cross_validate(l2_logistic_regression, X_train_prepared, np.ravel(y_train), cv=5,
                              scoring=['accuracy', 'precision', 'recall', 'f1'])

# Extract the mean scores for each metric
accuracy_l1 = cv_scores_l1['test_accuracy'].mean()
precision_l1 = cv_scores_l1['test_precision'].mean()
recall_l1 = cv_scores_l1['test_recall'].mean()
f1_l1 = cv_scores_l1['test_f1'].mean()

accuracy_l2 = cv_scores_l2['test_accuracy'].mean()
precision_l2 = cv_scores_l2['test_precision'].mean()
recall_l2 = cv_scores_l2['test_recall'].mean()
f1_l2 = cv_scores_l2['test_f1'].mean()

# Print the results
print('Logistic Regression with L1 Regularization')
print(f'Accuracy: {accuracy_l1:.4f}')
print(f'Precision: {precision_l1:.4f}')
print(f'Recall: {recall_l1:.4f}')
print(f'F1 score: {f1_l1:.4f}')

print('\nLogistic Regression with L2 Regularization')
print(f'Accuracy: {accuracy_l2:.4f}')
print(f'Precision: {precision_l2:.4f}')
print(f'Recall: {recall_l2:.4f}')
print(f'F1 score: {f1_l2:.4f}')
# Out:
# Logistic Regression with L1 Regularization
# Accuracy: 0.7119
# Precision: 0.5286
# Recall: 0.3619
# F1 score: 0.3857
#
# Logistic Regression with L2 Regularization
# Accuracy: 0.7124
# Precision: 0.5143
# Recall: 0.3952
# F1 score: 0.4210

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Train Random Forest classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_prepared, y_train)
X_test_prep=preprocessing_pipeline.fit_transform(X_test)
# Make predictions on test set
y_pred = rf.predict(X_test_prep)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Random Forest Classifier:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 score: {f1:.4f}")
# Out:
# C:\Users\shrus\AppData\Local\Temp\ipykernel_33056\2382929739.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train_prepared, y_train)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 6
#       4 rf = RandomForestClassifier(n_estimators=100, random_state=42)
#       5 rf.fit(X_train_prepared, y_train)
# ----> 6 X_test_prep=preprocessing_pipeline.fit_transform(X_test)
#       7 # Make predictions on test set
#       8 y_pred = rf.predict(X_test_prep)
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:437, in Pipeline.fit_transform(self, X, y, **fit_params)
#     410 """Fit the model and transform with the final estimator.
#     411
#     412 Fits all the transformers one after the other and transform the
#    (...)
#     434     Transformed samples.
#     435 """
#     436 fit_params_steps = self._check_fit_params(**fit_params)
# --> 437 Xt = self._fit(X, y, **fit_params_steps)
#     439 last_step = self._final_estimator
#     440 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:359, in Pipeline._fit(self, X, y, **fit_params_steps)
#     357     cloned_transformer = clone(transformer)
#     358 # Fit or load from cache the current transformer
# --> 359 X, fitted_transformer = fit_transform_one_cached(
#     360     cloned_transformer,
#     361     X,
#     362     y,
#     363     None,
#     364     message_clsname="Pipeline",
#     365     message=self._log_message(step_idx),
#     366     **fit_params_steps[name],
#     367 )
#     368 # Replace the transformer of the step with the fitted
#     369 # transformer. This is necessary when loading the transformer
#     370 # from the cache.
#     371 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\anaconda3\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:893, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891 with _print_elapsed_time(message_clsname, message):
#     892     if hasattr(transformer, "fit_transform"):
# --> 893         res = transformer.fit_transform(X, y, **fit_params)
#     894     else:
#     895         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:859, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     855 # non-optimized default implementation; override when a better
#     856 # method is possible for a given clustering algorithm
#     857 if y is None:
#     858     # fit method of arity 1 (unsupervised transformation)
# --> 859     return self.fit(X, **fit_params).transform(X)
#     860 else:
#     861     # fit method of arity 2 (supervised transformation)
#     862     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_base.py:390, in SimpleImputer.fit(self, X, y)
#     381 if self.verbose != "deprecated":
#     382     warnings.warn(
#     383         "The 'verbose' parameter was deprecated in version "
#     384         "1.1 and will be removed in 1.3. A warning will "
#    (...)
#     387         FutureWarning,
#     388     )
# --> 390 X = self._validate_input(X, in_fit=True)
#     392 # default fill_value is 0 for numerical input and "missing_value"
#     393 # otherwise
#     394 if self.fill_value is None:
#
# File ~\anaconda3\lib\site-packages\sklearn\impute\_base.py:327, in SimpleImputer._validate_input(self, X, in_fit)
#     324     force_all_finite = True
#     326 try:
# --> 327     X = self._validate_data(
#     328         X,
#     329         reset=in_fit,
#     330         accept_sparse="csc",
#     331         dtype=dtype,
#     332         force_all_finite=force_all_finite,
#     333         copy=self.copy,
#     334     )
#     335 except ValueError as ve:
#     336     if "could not convert" in str(ve):
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:546, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     544     raise ValueError("Validation should be done on X, y or both.")
#     545 elif not no_val_X and no_val_y:
# --> 546     X = check_array(X, input_name="X", **check_params)
#     547     out = X
#     548 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# TypeError: float() argument must be a string or a real number, not 'SimpleImputer'
